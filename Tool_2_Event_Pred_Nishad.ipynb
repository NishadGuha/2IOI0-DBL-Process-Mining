# %%
import pandas as pd
import os
from sklearn.model_selection import train_test_split
# from scipy.stats import mode
from statistics import mode
from statistics import mean
import operator
import functools
import datetime 
import numpy as np

# Read input
df1 = pd.read_csv('datasets/BPI Challenge 2017-training.csv')
df2 = pd.read_csv('datasets/BPI Challenge 2017-test.csv')
frames = [df1, df2]
df = pd.concat(frames)
df.reset_index(drop=True, inplace=True)

# %%
trace_list = [] # list of traces

for name, group in df.groupby(["case concept:name"]):
    trace_list.append(group['case concept:name'].tolist())

# %%
#define the function#
def find_list_features(list):
    list_len = [len(i) for i in list]
    return list_len

features = find_list_features(trace_list)

# Setting the limit for extreme traces
limit = np.percentile(features, 95)

# %%
# Calculating frequency of each trace
import collections, itertools
freq = collections.defaultdict(int)  # 0 by default
for x in itertools.chain.from_iterable(trace_list):
    freq[x] += 1
freq

# Filtering the frequency dictionary
filtered_dict = {k:v for k,v in freq.items() if v < limit}

# Making a list out of the keys
allowed_traces = [*filtered_dict]

# %%
# Final filter on the data frame   
df = df[df['case concept:name'].isin(allowed_traces)]

# %%
# Parse the timestamp and convert it into y-m-d form
df['event time:timestamp'] = pd.to_datetime(df['event time:timestamp'], format = '%d-%m-%Y %H:%M:%S.%f')

# Sort data by timestamp in ascending order
df.sort_values(['event time:timestamp'], axis=0, inplace=True)
    
# split into train set and test set (80/20)
df_train, df_test = train_test_split(df, test_size=0.2, shuffle = False)
# remove cases started in the training set
df_test = df_test[~df_test['case concept:name'].isin(df_train['case concept:name'].values)]

# Reset index
df_train.reset_index(drop=True, inplace=True)
df_test.reset_index(drop=True, inplace=True)

# Assign position number to each event
df_sort = df_train.set_index(df_train.groupby('case concept:name').cumcount(), append = True)

# %%
df_sort['day of the week'] = df_sort['event time:timestamp'].dt.dayofweek

# %%
avg_day = df_sort.groupby(level=1)['day of the week'].apply(
    lambda x: x.mean()
)

# %%
res = df_sort.merge(avg_day, left_on = df_sort.index.get_level_values(1).values, right_index = True, how = 'left')

# %%
res['predicted_week'] = res.groupby(level=1)['day of the week_x'].transform(lambda x: x) + res['day of the week_y']

# %%
res.predicted_week = res.predicted_week.astype(int)

# %%
res['predicted_week'] = np.where(res['predicted_week'] > 6, res['predicted_week'] - 6, res['predicted_week'])

# %%
# Idea is to find most common event per day of the week
l = len(res['event concept:name'])
lst = []
commonEventPerDay = []
dayList = res['day of the week_x'].tolist()
eventList = res['event concept:name'].tolist()

for j in range (0, 7):
    for i in range (0, l):
        if dayList[i] == j:
            lst.append(eventList[i])
    findMode = mode(lst)
    commonEventPerDay.append(findMode)
    list = []
        
commonEventPerDay
# Out:
# ['W_Call after offers',
#  'W_Call after offers',
#  'W_Call after offers',
#  'W_Validate application',
#  'W_Validate application',
#  'W_Call after offers',
#  'W_Call after offers']

# %%
# Predicted Event = Most Common Event for that Day of the Week
res['predicted_event'] = res['predicted_week']
for i in range (0, 7):
    res.loc[res['predicted_week'] == i, 'predicted_event'] = commonEventPerDay[i]

# %%
res
# Out:
#                   eventID            case LoanGoal case ApplicationType  \
# 0      0                 0  Existing loan takeover           New credit
# 1      1                 1  Existing loan takeover           New credit
# 2      2                 2  Existing loan takeover           New credit
# 3      3                 3  Existing loan takeover           New credit
# 4      4                 4  Existing loan takeover           New credit
# 5      5                 5  Existing loan takeover           New credit
# 16     4    Application_428409768               15000.0      Created
# 17     5    Application_428409768               15000.0  statechange
# 18     0    Application_828200680               35000.0      Created
# 19     1    Application_828200680               35000.0  statechange
# 20     2    Application_828200680               35000.0      Created
# 21     3    Application_828200680               35000.0      Deleted
# 22     4    Application_828200680               35000.0      Created
# 23     5    Application_828200680               35000.0  statechange
# 24     0   Application_1085880569               13000.0      Created
# 25     1   Application_1085880569               13000.0  statechange
# 26     2   Application_1085880569               13000.0      Created
# 27     3   Application_1085880569               13000.0      Deleted
# 28     4   Application_1085880569               13000.0      Created
# 29     5   Application_1085880569               13000.0  statechange
# ...                           ...                   ...          ...
# 851930 8   Application_1138682900               22000.0  statechange
# 851931 6   Application_1110847631               25000.0     Obtained
# 851932 9   Application_1138682900               22000.0  statechange
# 851933 10  Application_1138682900               22000.0      Deleted
# 851934 16  Application_1265044597               15000.0     Released
# 851935 11  Application_1138682900               22000.0      Created
# 851936 12  Application_1138682900               22000.0     Obtained
# 851937 13  Application_1138682900               22000.0  statechange
# 851938 15   Application_368529383                5000.0     Obtained
# 851939 30   Application_478367813               31000.0      Deleted
# 851940 31   Application_478367813               31000.0      Created
# 851941 32   Application_478367813               31000.0     Obtained
# 851942 33   Application_478367813               31000.0  statechange
# 851943 16   Application_368529383                5000.0     Released
# 851944 7   Application_1110847631               25000.0     Released
# 851945 34   Application_478367813               31000.0     Released
# 851946 6    Application_182597722               22000.0     Obtained
# 851947 14  Application_1138682900               22000.0     Released
# 851948 21  Application_1031465496               25000.0     Obtained
# 851949 24   Application_996050409               15000.0      Deleted
# 851950 25   Application_996050409               15000.0      Created
# 851951 26   Application_996050409               15000.0     Obtained
# 851952 27   Application_996050409               15000.0  statechange
# 851953 28   Application_996050409               15000.0  statechange
# 851954 22  Application_1031465496               25000.0     Released
# 851955 25  Application_1799331916                5000.0     Obtained
# 851956 26  Application_1799331916                5000.0     Released
# 851957 13   Application_643047755                   0.0     Obtained
# 851958 29   Application_996050409               15000.0     Released
# 851959 14   Application_643047755                   0.0     Released
#
#           event org:resource        event concept:name event EventOrigin  \
# 0      0              User_1      A_Create Application       Application
# 1      1              User_1               A_Submitted       Application
# 2      2              User_1            W_Handle leads          Workflow
# 3      3              User_1            W_Handle leads          Workflow
# 4      4              User_1    W_Complete application          Workflow
# 5      5              User_1                 A_Concept       Application
# 6      0              User_1      A_Create Application       Application
# 7      1              User_1               A_Submitted       Application
# 8      2              User_1            W_Handle leads          Workflow
# 9      3              User_1            W_Handle leads          Workflow
# 10     4              User_1    W_Complete application          Workflow
# 11     5              User_1                 A_Concept       Application
# 12     0              User_1      A_Create Application       Application
# 13     1              User_1               A_Submitted       Application
# 14     2              User_1            W_Handle leads          Workflow
# 15     3              User_1            W_Handle leads          Workflow
# 16     4              User_1    W_Complete application          Workflow
# 17     5              User_1                 A_Concept       Application
# 18     0              User_1      A_Create Application       Application
# 19     1              User_1               A_Submitted       Application
# 20     2              User_1            W_Handle leads          Workflow
# 21     3              User_1            W_Handle leads          Workflow
# 22     4              User_1    W_Complete application          Workflow
# 23     5              User_1                 A_Concept       Application
# 24     0              User_1      A_Create Application       Application
# 25     1              User_1               A_Submitted       Application
# 26     2              User_1            W_Handle leads          Workflow
# 27     3              User_1            W_Handle leads          Workflow
# 28     4              User_1    W_Complete application          Workflow
# 29     5              User_1                 A_Concept       Application
# ...                      ...                       ...               ...
# 851930 8              User_3                 O_Created             Offer
# 851931 6             User_65    W_Complete application          Workflow
# 851932 9              User_3  O_Sent (mail and online)             Offer
# 851933 10             User_3    W_Complete application          Workflow
# 851934 16            User_26       W_Call after offers          Workflow
# 851935 11             User_3       W_Call after offers          Workflow
# 851936 12             User_3       W_Call after offers          Workflow
# 851937 13             User_3                A_Complete       Application
# 851938 15            User_26       W_Call after offers          Workflow
# 851939 30            User_83    W_Validate application          Workflow
# 851940 31            User_83   W_Call incomplete files          Workflow
# 851941 32            User_83   W_Call incomplete files          Workflow
# 851942 33            User_83              A_Incomplete       Application
# 851943 16            User_26       W_Call after offers          Workflow
# 851944 7             User_65    W_Complete application          Workflow
# 851945 34            User_83   W_Call incomplete files          Workflow
# 851946 6             User_65    W_Complete application          Workflow
# 851947 14             User_3       W_Call after offers          Workflow
# 851948 21            User_26       W_Call after offers          Workflow
# 851949 24           User_113       W_Call after offers          Workflow
# 851950 25           User_113    W_Validate application          Workflow
# 851951 26           User_113    W_Validate application          Workflow
# 851952 27           User_113              A_Validating       Application
# 851953 28           User_113                O_Returned             Offer
# 851954 22            User_26       W_Call after offers          Workflow
# 851955 25            User_26       W_Call after offers          Workflow
# 851956 26            User_26       W_Call after offers          Workflow
# 851957 13            User_26       W_Call after offers          Workflow
# 851958 29           User_113    W_Validate application          Workflow
# 851959 14            User_26       W_Call after offers          Workflow
#
#                     event EventID event lifecycle:transition  \
# 0      0    Application_652823628                   complete
# 1      1     ApplState_1582051990                   complete
# 2      2      Workitem_1298499574                   schedule
# 3      3      Workitem_1673366067                   withdraw
# 4      4      Workitem_1493664571                   schedule
# 5      5      ApplState_642383566                   complete
# 6      0   Application_1691306052                   complete
# 7      1      ApplState_284636842                   complete
# 8      2       Workitem_831373279                   schedule
# 9      3      Workitem_1299098074                   withdraw
# 10     4      Workitem_1703931302                   schedule
# 11     5      ApplState_421204851                   complete
# 12     0    Application_428409768                   complete
# 13     1      ApplState_105207793                   complete
# 14     2      Workitem_1185806608                   schedule
# 15     3       Workitem_835967796                   withdraw
# 16     4       Workitem_755889823                   schedule
# 17     5     ApplState_1727723699                   complete
# 18     0    Application_828200680                   complete
# 19     1      ApplState_420123528                   complete
# 20     2      Workitem_1645277487                   schedule
# 21     3      Workitem_1902399339                   withdraw
# 22     4      Workitem_1933317539                   schedule
# 23     5      ApplState_281446729                   complete
# 24     0   Application_1085880569                   complete
# 25     1      ApplState_736842791                   complete
# 26     2       Workitem_957861555                   schedule
# 27     3       Workitem_237665452                   withdraw
# 28     4       Workitem_111979908                   schedule
# 29     5     ApplState_1145436902                   complete
# ...                           ...                        ...
# 851930 8    OfferState_1924728738                   complete
# 851931 6      Workitem_1696494136                      start
# 851932 9    OfferState_2046501407                   complete
# 851933 10     Workitem_2028417033                   withdraw
# 851934 16     Workitem_2041933453                    suspend
# 851935 11      Workitem_776195490                   schedule
# 851936 12      Workitem_419557985                      start
# 851937 13    ApplState_1217618091                   complete
# 851938 15      Workitem_853526678                     resume
# 851939 30      Workitem_448538000                  ate_abort
# 851939 30 2016-10-26 09:06:40.913                  2           2.128800
# 851940 31 2016-10-26 09:06:40.918                  2           2.138156
# 851941 32 2016-10-26 09:06:40.920                  2           2.140250
# 851942 33 2016-10-26 09:06:40.923                  2           2.148980
# 851943 16 2016-10-26 09:06:47.514                  2           2.118063
# 851944 7  2016-10-26 09:06:58.498                  2           2.116509
# 851945 34 2016-10-26 09:07:06.267                  2           2.146588
# 851946 6  2016-10-26 09:07:09.715                  2           2.115066
# 851947 14 2016-10-26 09:07:23.354                  2           2.116215
# 851948 21 2016-10-26 09:07:55.519                  2           2.171154
# 851949 24 2016-10-26 09:08:13.876                  2           2.128410
# 851950 25 2016-10-26 09:08:13.881                  2           2.108341
# 851951 26 2016-10-26 09:08:13.883                  2           2.098071
# 851952 27 2016-10-26 09:08:14.594                  2           2.100694
# 851953 28 2016-10-26 09:08:22.232                  2           2.107976
# 851954 22 2016-10-26 09:08:32.681                  2           2.150439
# 851955 25 2016-10-26 09:08:49.785                  2           2.108341
# 851956 26 2016-10-26 09:09:26.913                  2           2.098071
# 851957 13 2016-10-26 09:09:31.392                  2           2.115876
# 851958 29 2016-10-26 09:09:55.881                  2           2.118145
# 851959 14 2016-10-26 09:10:01.753                  2           2.116215
#
#            predicted_week         predicted_event
# 0      0                6     W_Call after offers
# 1      1                6     W_Call after offers
# 2      2                6     W_Call after offers
# 3      3                6     W_Call after offers
# 4      4                6     W_Call after offers
# 5      5                6     W_Call after offers
# 6      0                6     W_Call after offers
# 7      1                6     W_Call after offers
# 8      2                6     W_Call after offers
# 9      3                6     W_Call after offers
# 10     4                6     W_Call after offers
# 11     5                6     W_Call after offers
# 12     0                6     W_Call after offers
# 13     1                6     W_Call after offers
# 14     2                6     W_Call after offers
# 15     3                6     W_Call after offers
# 16     4                6     W_Call after offers
# 17     5                6     W_Call after offers
# 18     0                6     W_Call after offers
# 19     1                6     W_Call after offers
# 20     2                6     W_Call after offers
# 21     3                6     W_Call after offers
# 22     4                6     W_Call after offers
# 23     5                6     W_Call after offers
# 24     0                6     W_Call after offers
# 25     1                6     W_Call after offers
# 26     2                6     W_Call after offers
# 27     3                6     W_Call after offers
# 28     4                6     W_Call after offers
# 29     5                6     W_Call after offers
# ...                   ...                     ...
# 851930 8                4  W_Validate application
# 851931 6                4  W_Validate application
# 851932 9                4  W_Validate application
# 851933 10               4  W_Validate application
# 851934 16               4  W_Validate application
# 851935 11               4  W_Validate application
# 851936 12               4  W_Validate application
# 851937 13               4  W_Validate application
# 851938 15               4  W_Validate application
# 851939 30               4  W_Validate application
# 851940 31               4  W_Validate application
# 851941 32               4  W_Validate application
# 851942 33               4  W_Validate application
# 851943 16               4  W_Validate application
# 851944 7                4  W_Validate application
# 851945 34               4  W_Validate application
# 851946 6                4  W_Validate application
# 851947 14               4  W_Validate application
# 851948 21               4  W_Validate application
# 851949 24               4  W_Validate application
# 851950 25               4  W_Validate application
# 851951 26               4  W_Validate application
# 851952 27               4  W_Validate application
# 851953 28               4  W_Validate application
# 851954 22               4  W_Validate application
# 851955 25               4  W_Validate application
# 851956 26               4  W_Validate application
# 851957 13               4  W_Validate application
# 851958 29               4  W_Validate application
# 851959 14               4  W_Validate application
#
# [851960 rows x 16 columns]
