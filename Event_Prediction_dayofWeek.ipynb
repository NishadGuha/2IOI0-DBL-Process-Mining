# %%
import pandas as pd
import os
from sklearn.model_selection import train_test_split
# from scipy.stats import mode
from statistics import mode
import operator
import functools
import datetime 
import numpy as np

# Read input
df1 = pd.read_csv('datasets/BPI Challenge 2017-training.csv')
df2 = pd.read_csv('datasets/BPI Challenge 2017-test.csv')
frames = [df1, df2]
df = pd.concat(frames)
df.reset_index(drop=True, inplace=True)


# Parse the timestamp and convert it into y-m-d form
df['event time:timestamp'] = pd.to_datetime(df['event time:timestamp'], format = '%d-%m-%Y %H:%M:%S.%f')

# Sort data by timestamp in ascending order
df.sort_values(['event time:timestamp'], axis=0, inplace=True)
    
# split into train set and test set (80/20)
df_train, df_test = train_test_split(df, test_size=0.2, shuffle = False)
# remove cases started in the training set
df_test = df_test[~df_test['case concept:name'].isin(df_train['case concept:name'].values)]

# Reset index
df_train.reset_index(drop=True, inplace=True)
df_test.reset_index(drop=True, inplace=True)

# Assign position number to each event
df_sort = df_train.set_index(df_train.groupby('case concept:name').cumcount(), append = True)

# %%
df_sort['day of the week'] = df_sort['event time:timestamp'].dt.dayofweek

# %%
avg_day = df_sort.groupby(level=1)['day of the week'].apply(
    lambda x: x.mean()
)

# %%
res = df_sort.merge(avg_day, left_on = df_sort.index.get_level_values(1).values, right_index = True, how = 'left')

# %%
res['predicted_week'] = res.groupby(level=1)['day of the week_x'].transform(lambda x: x) + res['day of the week_y']

# %%
res.predicted_week = res.predicted_week.astype(int)

# %%
res['predicted_week'] = np.where(res['predicted_week'] > 6, res['predicted_week'] - 6, res['predicted_week'])

# %%
# Idea is to find most common event per day of the week
l = len(res['event concept:name'])
lst = []
commonEventPerDay = []
dayList = res['day of the week_x'].tolist()
eventList = res['event concept:name'].tolist()

for j in range (0, 7):
    for i in range (0, l):
        if dayList[i] == j:
            lst.append(eventList[i])
    findMode = mode(lst)
    commonEventPerDay.append(findMode)
    list = []
        
commonEventPerDay
# Out:
# ['W_Call after offers',
#  'W_Call after offers',
#  'W_Validate application',
#  'W_Validate application',
#  'W_Validate application',
#  'W_Validate application',
#  'W_Validate application']

# %%
# Predicted Event = Most Common Event for that Day of the Week
res['predicted_event'] = res['predicted_week']
for i in range (0, 7):
    res.loc[res['predicted_week'] == i, 'predicted_event'] = commonEventPerDay[i]

# %%
res
# Out:
#                   eventID            case LoanGoal case ApplicationType  \
# 0      0                 0  Existing loan takeover           New credit
# 1      1                 1  Existing loan takeover           New credit
# 2      2                 2  Existing loan takeover           New credit
# 3      3                 3  Existing loan takeover           New credit
# 4      4                 4  Existing loan takeover           New credit
# 5      5                 5  Existing loan takeover           New credit
# 6      0        4294967296        Home improvement           New credit
# 7      1        4294967297        Home improvement           New credit
# 8      2        4294967298        Home improvement           New credit
# 9      3        4294967299        Home improvement           New credit
# 10     4        4294967300        Home improvement           New credit
# 11     5        4294967301        Home improvement           New credit
# 12     0        8589934592        Home improvement           New credit
# 13     1        8589934593        Home improvement           New credit
# 14     2        8589934594        Home improvement           New credit
# 15     3        8589934595        Home improvement           New credit
# 16     4        8589934596        Home improvement           New credit
# 17     5        8589934597        Home improvement           New credit
# 18     0       12884901888                     Car           New credit
# 19     1       12884901889                     Car           New credit
# 20     2       12884901890                     Car           New credit
# 21     0       17179869184        Home improvement           New credit
# 22     1       17179869185        Home improvement           New credit
# 23     2       17179869186        Home improvement           New credit
# 24     3       17179869187        Home improvement           New credit
# 25     4       17179869188        Home improvement           New credit
# 26     5       17179869189        Home improvement           New credit
# 27     0       21474836480  Existing loan takeover           New credit
# 28     1       21474836481  Existing loan takeover           New credit
# 29     2       21474836482  Existing loan takeover           New credit
# ...                    ...                     ...                  ...
# 961783 39  105750684762151                     Car          Limit raise
# 961784 32  107498736451616                     Car           New credit
# 961785 33  107498736451617                     Car           New credit
# 961786 34  107498736451618                     Car           New credit
# 961787 35  107498736451619                     Car           New credit
# 961788 18  111304077475858        Home improvement          Limit raise
# 961789 15  111849538322447        Home improvement           New credit
# 961790 36  107498736451620                     Car           New credit
# 961791 8   111462991265800  Other, see explanation           New credit
# 961792 9   111462991265801  Other, see explanation           New credit
# 961793 11  110732846825483  Existing loan takeover           New credit
# 961794 12  110732846825484  Existing loan takeover           New credit
# 961795 21  108843061215253  Other, see explanation          Limit raise
# 961796 22  108843061215254  Other, see explanation          Limit raise
# 961797 23  108843061215255  Other, see explanation          Limit raise
# 961798 13  110732846825485  Existing loan takeover           New credit
# 961799 14  110732846825486  Existing loan takeover           New credit
# 961800 15  110732846825487  Existing loan takeover           New credit
# 961801 16  110732846825488  Existing loan takeover           New credit
# 961802 17  110732846825489  Existing loan takeover           New credit
# 961803 10  111462991265802  Other, see explanation           New credit
# 961804 11  111462991265803  Other, see explanation           New credit
# 961805 12  111462991265804  Other, see explanation           New credit
# 961806 13  111462991265805  Other, see explanation           New credit
# 961807 14  111462991265806  Other, see explanation           New credit
# 961808 18  110732846825490  Existing loan takeover           New credit
# 961809 32  108142981546016     Remaining debt home           New credit
# 961810 24  109474421407768        Home improvement           New credit
# 961811 31  108181636251679                     Car           New credit
# 961812 32  108181636251680                     Car           New credit
#
#                 case concept:name  case RequestedAmount event Action  \
# 0      0    Application_652823628               20000.0      Created
# 1      1    Application_652823628               20000.0  statechange
# 2      2    Application_652823628               20000.0      Created
# 3      3    Application_652823628               20000.0      Deleted
# 4      4    Application_652823628               20000.0      Created
# 5      5    Application_652823628               20000.0  statechange
# 6      0   Application_1691306052               10000.0      Created
# 7      1   Application_1691306052               10000.0  statechange
# 8      2   Application_1691306052               10000.0      Created
# 9      3   Application_1691306052               10000.0      Deleted
# 10     4   Application_1691306052               10000.0      Created
# 11     5   Application_1691306052               10000.0  statechange
# 12     0    Application_428409768               15000.0      Created
# 13     1    Application_428409768               15000.0  statechange
# 14     2    Application_428409768               15000.0      Created
# 15     3    Application_428409768               15000.0      Deleted
# 16     4    Application_428409768               15000.0      Created
# 17     5    Application_428409768               15000.0  statechange
# 18     0   Application_1746793196                5000.0      Created
# 19     1   Application_1746793196                5000.0  statechange
# 20     2   Application_1746793196                5000.0      Created
# 21     0    Application_828200680               35000.0      Created
# 22     1    Application_828200680               35000.0  statechange
# 23     2    Application_828200680               35000.0      Created
# 24     3    Application_828200680               35000.0      Deleted
# 25     4    Application_828200680               35000.0      Created
# 26     5    Application_828200680               35000.0  statechange
# 27     0   Application_1085880569               13000.0      Created
# 28     1   Application_1085880569               13000.0  statechange
# 29     2   Application_1085880569               13000.0      Created
# ...                           ...                   ...          ...
# 961783 39  Application_2021390880                   0.0     Released
# 961784 32  Application_1931050520                5000.0      Deleted
# 961785 33  Application_1931050520                5000.0      Created
# 961786 34  Application_1931050520                5000.0     Obtained
# 961787 35  Application_1931050520                5000.0  statechange
# 961788 18   Application_548136507               20000.0     Released
# 961789 15  Application_1744217682               15000.0     Released
# 961790 36  Application_1931050520                5000.0     Released
# 961791 8    Application_752373732                7000.0      Created
# 961792 9    Application_752373732                7000.0  statechange
# 961793 11  Application_2048381730               30000.0      Created
# 961794 12  Application_2048381730               30000.0  statechange
# 961795 21  Application_1375807341                   0.0  statechange
# 961796 22  Application_1375807341                   0.0  statechange
# 961797 23  Application_1375807341                   0.0      Deleted
# 961798 13  Application_2048381730               30000.0  statechange
# 961799 14  Application_2048381730               30000.0      Deleted
# 961800 15  Application_2048381730               30000.0      Created
# 961801 16  Application_2048381730               30000.0     Obtained
# 961802 17  Application_2048381730               30000.0  statechange
# 961803 10   Application_752373732                7000.0  statechange
# 961804 11   Application_752373732                7000.0      Deleted
# 961805 12   Application_752373732                7000.0      Created
# 961806 13   Application_752373732                7000.0     Obtained
# 961807 14   Application_752373732                7000.0  statechange
# 961808 18  Application_2048381730               30000.0     Released
# 961809 32  Application_1385143613               25000.0     Released
# 961810 24  Application_1273835556               60000.0     Obtained
# 961811 31   Application_259502445                6000.0      Deleted
# 961812 32   Application_259502445                6000.0      Created
#
#           event org:resource        event concept:name event EventOrigin  \
# 0      0              User_1      A_Create Application       Application
# 1      1              User_1               A_Submitted       Application
# 2      2              User_1            W_Handle leads          Workflow
# 3      3              User_1            W_Handle leads          Workflow
# 4      4              User_1    W_Complete application          Workflow
# 5      5              User_1                 A_Concept       Application
# 6      0              User_1      A_Create Application       Application
# 7      1              User_1               A_Submitted       Application
# 8      2              User_1            W_Handle leads          Workflow
# 9      3              User_1            W_Handle leads          Workflow
# 10     4              User_1    W_Complete application          Workflow
# 11     5              User_1                 A_Concept       Application
# 12     0              User_1      A_Create Application       Application
# 13     1              User_1               A_Submitted       Application
# 14     2              User_1            W_Handle leads          Workflow
# 15     3              User_1            W_Handle leads          Workflow
# 16     4              User_1    W_Complete application          Workflow
# 17     5              User_1                 A_Concept       Application
# 18     0              User_1      A_Create Application       Application
# 19     1              User_1               A_Submitted       Application
# 20     2              User_1            W_Handle leads          Workflow
# 21     0              User_1      A_Create Application       Application
# 22     1              User_1               A_Submitted       Application
# 23     2              User_1            W_Handle leads          Workflow
# 24     3              User_1            W_Handle leads          Workflow
# 25     4              User_1    W_Complete application          Workflow
# 26     5              User_1                 A_Concept       Application
# 27     0              User_1      A_Create Application       Application
# 28     1              User_1               A_Submitted       Application
# 29     2              User_1            W_Handle leads          Workflow
# ...                      ...                       ...               ...
# 961783 39            User_87   W_Call incomplete files          Workflow
# 961784 32           User_118   W_Call incomplete files          Workflow
# 961785 33           User_118    W_Validate application          Workflow
# 961786 34           User_118    W_Validate application          Workflow
# 961787 35           User_118              A_Validating       Application
# 961788 18            User_84       W_Call after offers          Workflow
# 961789 15            User_65       W_Call after offers          Workflow
# 961790 36           User_118    W_Validate application          Workflow
# 961791 8             User_96            O_Create Offer             Offer
# 961792 9             User_96                 O_Created             Offer
# 961793 11             User_2            O_Create Offer             Offer
# 961794 12             User_2                 O_Created             Offer
# 961795 21           User_109                O_Accepted             Offer
# 961796 22           User_109                 A_Pending       Application
# 961797 23           User_109    W_Validate application          Workflow
# 961798 13             User_2  O_Sent (mail and online)             Offer
# 961799 14             User_2    W_Complete application          Workflow
# 961800 15             User_2       W_Call after offers          Workflow
# 961801 16             User_2       W_Call after offers          Workflow
# 961802 17             User_2                A_Complete       Application
# 961803 10            User_96  O_Sent (mail and online)             Offer
# 961804 11            User_96    W_Complete application          Workflow
# 961805 12            User_96       W_Call after offers          Workflow
# 961806 13            User_96       W_Call after offers          Workflow
# 961807 14            User_96                A_Complete       Application
# 961808 18             User_2       W_Call after offers          Workflow
# 961809 32            User_14   W_Call incomplete files          Workflow
# 961810 24            User_14   W_Call incomplete files          Workflow
# 961811 31           User_118   W_Call incomplete files          Workflow
# 961812 32           User_118    W_Validate application          Workflow
#
#                     event EventID event lifecycle:transition  \
# 0      0    Application_652823628                   complete
# 1      1     ApplState_1582051990                   complete
# 2      2      Workitem_1298499574                   schedule
# 3      3      Workitem_1673366067                   withdraw
# 4      4      Workitem_1493664571                   schedule
# 5      5      ApplState_642383566                   complete
# 6      0   Application_1691306052                   complete
# 7      1      ApplState_284636842                   complete
# 8      2       Workitem_831373279                   schedule
# 9      3      Workitem_1299098074                   withdraw
# 10     4      Workitem_1703931302                   schedule
# 11     5      ApplState_421204851                   complete
# 12     0    Application_428409768                   complete
# 13     1      ApplState_105207793                   complete
# 14     2      Workitem_1185806608                   schedule
# 15     3       Workitem_835967796                   withdraw
# 16     4       Workitem_755889823                   schedule
# 17     5     ApplState_1727723699                   complete
# 18     0   Application_1746793196                   complete
# 19     1      ApplState_282472804                   complete
# 20     2      Workitem_1676837235                   schedule
# 21     0    Application_828200680                   complete
# 22     1      ApplState_420123528                   complete
# 23     2      Workitem_1645277487                   schedule
# 24     3      Workitem_1902399339                   withdraw
# 25     4      Workitem_1933317539                   schedule
# 26     5      ApplState_281446729                   complete
# 27     0   Application_1085880569                   complete
# 28     1      ApplState_736842791                   complete
# 29     2       Workitem_957861555                   schedule
# ...                           ...                        ...
# 961783 39       Workitem_30642025                    suspend
# 961784 32      Workitem_969751210                  ate_abort
# 961785 33      Workitem_685401266                   schedule
# 961786 34      Workitem_523411455                      start
# 961787 35     ApplState_833861869                   complete
# 961788 18       Workitem_39121199                    suspend
# 961789 15      Workitem_978781482                    suspend
# 961790 36     Workitem_1593464463                    suspend
# 961791 8         Offer_1375981245                   complete
# 961792 9     OfferState_711073253                   complete
# 961793 11        Offer_1312955969                   complete
# 961794 12     OfferState_85266321                   complete
# 961795 21      OfferState_4824059                   complete
# 961796 22      ApplState_67422461                   complete
# 961797 23     Workitem_1277551969                  ate_abort
# 961798 13   OfferState_1471909142                   complete
# 961799 14     Workitem_1884095173                  ate_abort
# 961800 15     Workitem_2107487277                   schedule
# 961801 16     Workitem_1437454525                      start
# 961802 17     ApplState_189414897                   complete
# 961803 10    OfferState_211694290                   complete
# 961804 11      Workitem_266298208                   complete
# 961805 12     Workitem_1121534364                   schedule
# 961806 13      Workitem_366045603                      start
# 961807 14    ApplState_1830765979                   complete
# 961808 18      Workitem_458551822                    suspend
# 961809 32      Workitem_816570513                    suspend
# 961810 24     Workitem_1843181301                     resume
# 961811 31     Workitem_2066573185                  ate_abort
# 961812 32      Workitem_857721777                   schedule
#
#              event time:timestamp  day of the week_x  day of the week_y  \
# 0      0  2016-01-01 10:51:15.304                  4           2.412447
# 1      1  2016-01-01 10:51:15.352                  4           2.412447
# 2      2  2016-01-01 10:51:15.774                  4           2.412447
# 3      3  2016-01-01 10:52:36.392                  4           2.340845
# 4      4  2016-01-01 10:52:36.403                  4           2.340884
# 5      5  2016-01-01 10:52:36.413                  4           2.360355
# 6      0  2016-01-01 11:16:11.500                  4           2.412447
# 7      1  2016-01-01 11:16:11.549                  4           2.412447
# 8      2  2016-01-01 11:16:11.740                  4           2.412447
# 9      3  2016-01-01 11:17:31.573                  4           2.340845
# 10     4  2016-01-01 11:17:31.584                  4           2.340884
# 11     5  2016-01-01 11:17:31.594                  4           2.360355
# 12     0  2016-01-01 12:19:38.177                  4           2.412447
# 13     1  2016-01-01 12:19:38.235                  4           2.412447
# 14     2  2016-01-01 12:19:38.914                  4           2.412447
# 15     3  2016-01-01 12:20:37.391                  4           2.340845
# 16     4  2016-01-01 12:20:37.409                  4           2.340884
# 17     5  2016-01-01 12:20:37.422                  4           2.360355
# 18     0  2016-01-01 13:34:53.911                  4           2.412447
# 19     1  2016-01-01 13:34:53.950                  4           2.412447
# 20     2  2016-01-01 13:34:54.320                  4           2.412447
# 21     0  2016-01-01 14:00:04.360                  4           2.412447
# 22     1  2016-01-01 14:00:04.398                  4           2.412447
# 23     2  2016-01-01 14:00:04.737                  4           2.412447
# 24     3  2016-01-01 14:01:44.651                  4           2.340845
# 25     4  2016-01-01 14:01:44.661                  4           2.340884
# 26     5  2016-01-01 14:01:44.671                  4           2.360355
# 27     0  2016-01-01 14:05:19.866                  4           2.412447
# 28     1  2016-01-01 14:05:19.901                  4           2.412447
# 29     2  2016-01-01 14:05:20.088                  4           2.412447
# ...                           ...                ...                ...
# 961783 39 2016-10-27 11:07:20.702                  3           2.126851
# 961784 32 2016-10-27 11:07:54.259                  3           2.142530
# 961785 33 2016-10-27 11:07:54.265                  3           2.149343
# 961786 34 2016-10-27 11:07:54.267                  3           2.151351
# 961787 35 2016-10-27 11:07:54.320                  3           2.146746
# 961788 18 2016-10-27 11:09:29.801                  3           2.143160
# 961789 15 2016-10-27 11:10:05.076                  3           2.146063
# 961790 36 2016-10-27 11:10:51.901                  3           2.155934
# 961791 8  2016-10-27 11:11:59.922                  3           2.104359
# 961792 9  2016-10-27 11:12:00.507                  3           2.135680
# 961793 11 2016-10-27 11:12:00.706                  3           2.127626
# 961794 12 2016-10-27 11:12:01.525                  3           2.125266
# 961795 21 2016-10-27 11:12:04.280                  3           2.165718
# 961796 22 2016-10-27 11:12:04.284                  3           2.148781
# 961797 23 2016-10-27 11:12:04.286                  3           2.138559
# 961798 13 2016-10-27 11:12:16.843                  3           2.121063
# 961799 14 2016-10-27 11:12:16.855                  3           2.121675
# 961800 15 2016-10-27 11:12:16.866                  3           2.146063
# 961801 16 2016-10-27 11:12:16.871                  3           2.119861
# 961802 17 2016-10-27 11:12:16.872                  3           2.142420
# 961803 10 2016-10-27 11:12:41.815                  3           2.126042
# 961804 11 2016-10-27 11:12:41.826                  3           2.127626
# 961805 12 2016-10-27 11:12:41.831                  3           2.125266
# 961806 13 2016-10-27 11:12:41.833                  3           2.121063
# 961807 14 2016-10-27 11:12:41.834                  3           2.121675
# 961808 18 2016-10-27 11:13:41.439                  3           2.143160
# 961809 32 2016-10-27 11:14:18.490                  3           2.142530
# 961810 24 2016-10-27 11:14:22.469                  3           2.131916
# 961811 31 2016-10-27 11:15:07.489                  3           2.137054
# 961812 32 2016-10-27 11:15:07.497                  3           2.142530
#
#            predicted_week         predicted_event
# 0      0                6  W_Validate application
# 1      1                6  W_Validate application
# 2      2                6  W_Validate application
# 3      3                6  W_Validate application
# 4      4                6  W_Validate application
# 5      5                6  W_Validate application
# 6      0                6  W_Validate application
# 7      1                6  W_Validate application
# 8      2                6  W_Validate application
# 9      3                6  W_Validate application
# 10     4                6  W_Validate application
# 11     5                6  W_Validate application
# 12     0                6  W_Validate application
# 13     1                6  W_Validate application
# 14     2                6  W_Validate application
# 15     3                6  W_Validate application
# 16     4                6  W_Validate application
# 17     5                6  W_Validate application
# 18     0                6  W_Validate application
# 19     1                6  W_Validate application
# 20     2                6  W_Validate application
# 21     0                6  W_Validate application
# 22     1                6  W_Validate application
# 23     2                6  W_Validate application
# 24     3                6  W_Validate application
# 25     4                6  W_Validate application
# 26     5                6  W_Validate application
# 27     0                6  W_Validate application
# 28     1                6  W_Validate application
# 29     2                6  W_Validate application
# ...                   ...                     ...
# 961783 39               5  W_Validate application
# 961784 32               5  W_Validate application
# 961785 33               5  W_Validate application
# 961786 34               5  W_Validate application
# 961787 35               5  W_Validate application
# 961788 18               5  W_Validate application
# 961789 15               5  W_Validate application
# 961790 36               5  W_Validate application
# 961791 8                5  W_Validate application
# 961792 9                5  W_Validate application
# 961793 11               5  W_Validate application
# 961794 12               5  W_Validate application
# 961795 21               5  W_Validate application
# 961796 22               5  W_Validate application
# 961797 23               5  W_Validate application
# 961798 13               5  W_Validate application
# 961799 14               5  W_Validate application
# 961800 15               5  W_Validate application
# 961801 16               5  W_Validate application
# 961802 17               5  W_Validate application
# 961803 10               5  W_Validate application
# 961804 11               5  W_Validate application
# 961805 12               5  W_Validate application
# 961806 13               5  W_Validate application
# 961807 14               5  W_Validate application
# 961808 18               5  W_Validate application
# 961809 32               5  W_Validate application
# 961810 24               5  W_Validate application
# 961811 31               5  W_Validate application
# 961812 32               5  W_Validate application
#
# [961813 rows x 16 columns]
